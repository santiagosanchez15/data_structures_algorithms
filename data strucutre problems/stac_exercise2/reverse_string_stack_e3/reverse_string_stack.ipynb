# %% [markdown]
# # Exercise 3
# Implement reverse_string(s) that reverses a string using a stack. Do not use Python's built-in
# reverse or slicing like s[::-1].

# %%
#lets import our Stack class 
import sys
sys.path.append('../') # tells python to look on this address and goes up to stac_exercise2

# from class_stack import Stack
from implement_a_stack_e1.class_stack import Stack #path of folder, then file, then what we want to import

# %% [markdown]
# # function to reverse the string using a stack

# %%
def reverse_string(s: str) -> str:
    '''Reverse a string using a stack'''

    stack = list(s)
    new_string = ""
    for i in range(len(s)):
        new_string += stack.pop()
    return new_string

# %%
#unit testing
my_list = ['hello', 'racecar', 'stack']
for element in my_list:
    print(reverse_string(element))
# Out:
# olleh
# racecar
# kcats
